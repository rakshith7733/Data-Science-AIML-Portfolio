# %% [markdown]
# $$ Day 5: Lists $$

# %% [markdown]
# ```py
# There are four collection / Non-Premitive datatypes in Python:
#
# 1. List
# 2. Tuples
# 3. Sets
# 4. Dictionary
#
# ##### Lists:
# - It is a collection of ordered, different datatype and changable(modifiable). Allows duplicate.
# - A list can be empty or can have different datatypes.
#
# ```

# %%
#In built List function
lst = list()

#Creating empty list. enclosed with square 
lst1 = []

# %%
#Creating a list
fruits = ["Apple","Banana","Grapes",'Orange']
print(fruits)
# Out:
# ['Apple', 'Banana', 'Grapes', 'Orange']

# %%
#length of the list using in built len() function.
print(len(fruits))
# Out:
# 4

# %%
#collection of different datatypes
lst_1 = [1,"Rakshith",26,"Banglore",{"course":"python"}]
print(lst_1)
print(len(lst_1))
# Out:
# [1, 'Rakshith', 26, 'Banglore', {'course': 'python'}]
# 5

# %% [markdown]
# ```Accessing List Items using Indexing```

# %% [markdown]
# - We can access item in a list using inxeding. A index starts from 0.

# %%
#access "banglore" using index position
print(lst_1[3])
# Out:
# Banglore

# %%
#last index
last_index = len(lst_1) - 1
print(last_index)
# Out:
# 4

# %% [markdown]
# ```Accessing List items using Negative Indexing```

# %%
#Access last item
print(lst_1[-1])
# Out:
# {'course': 'python'}

# %%
#access age through negative indexing
print(lst_1[-3])
# Out:
# 26

# %% [markdown]
# ```Unpacking list items```

# %%
item = ['item1','item2','item3', 'item4', 'item5']

#*rest is used to assigin remaining items to rest variable.
f_item,sec_item,th_item,*rest = item
print(f_item)
print(sec_item)
print(th_item)
print(rest)
# Out:
# item1
# item2
# item3
# ['item4', 'item5']

# %% [markdown]
# ```Slicing Items from a list```
#
# - We can specify a range of positive indexes by the start and end and even the step to return value.
#
# - Indexing format:
#            [start: stop: step]

# %%
fruits = ["Apple","Banana","Grapes",'Orange']

#Positive Indexing
#range 1:3
print(fruits[1:3])

#skip first and pull all items
print(fruits[1:])

#slice the alternate items
print(fruits[::2])
# Out:
# ['Banana', 'Grapes']
# ['Banana', 'Grapes', 'Orange']
# ['Apple', 'Grapes']

# %%
#Negative Indexing

#it doesn't include last and goes down
print(fruits[-3:-1])

#-3 to all the way up
print(fruits[-3:])

#Reverse a list using negative index
print(lst_1[::-1])
# Out:
# ['Banana', 'Grapes']
# ['Banana', 'Grapes', 'Orange']
# [{'course': 'python'}, 'Banglore', 26, 'Rakshith', 1]
